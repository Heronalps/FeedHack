# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', 150)
import spacy
print('The spaCy version is {}.'.format(spacy.__version__))
from spacy.lang.en import English
from spacy.tokenizer import Tokenizer
import contractions
import re

import bert
# Out:
# The spaCy version is 2.1.6.

# %% [markdown]
# ## Load and filter data

# %%
n = 1000
uif = pd.read_csv('./uif_data_100k.tsv', sep='\t')
print(uif.shape)
uif['PostTextInEnglish'].iloc[n]
# Out:
# (100000, 2)
# 'Code: 0x803fb005 |'

# %%
print (uif.columns)
# Out:
# Index(['Unnamed: 0', 'PostTextInEnglish'], dtype='object')

# %%
uif.rename(columns={'Unnamed: 0': 'Id','PostTextInEnglish':'verbatim'}, inplace=True)
print (uif.columns)
# Out:
# Index(['Id', 'verbatim'], dtype='object')

# %%
# Replace separator
uif['verbatim'] = uif['verbatim'].apply(lambda x: x.replace(" |", "."))

# Remove NULL lines
uif = uif[uif['verbatim']!='#NULL#']
uif.head()
# Out:
#          Id  \
# 0   5059664
# 2   4745123
# 4   1816600
# 5  10328111
# 6   3491640
#
#                                                                                                                                                 verbatim
# 0                                                                                                                                                    to.
# 2  bbc.com I keep on getting ads on this web site from Australia while I am logged into this site its absolutely so frustrating so how can I get rid ...
# 4                                                                                                                                        You don't hear.
# 5                                                                                   Can t reach this page https://login.comcast.net/login?r=comcast.net.
# 6  My laptop is not communicating with the printer   I get the message:   Cannot communicate with the printer. Turn Enable bi-directional support on ...

# %%
uif.tail(100)
# Out:
#              Id  \
# 99863   9891094
# 99865   4967024
# 99866   5956972
# 99867   9683155
# 99868   6637733
# 99869   2164214
# 99870   3825001
# 99871   9355201
# 99872   9715512
# 99873   6334109
# 99876   7008958
# 99878   2730299
# 99881   9838864
# 99882  11818082
# 99883   3836902
# 99884    885762
# 99885   3815269
# 99886    101450
# 99888   9158057
# 99891   3178312
# 99892   6917129
# 99894   8808265
# 99895  10027194
# 99896  10215665
# 99897   7015046
# 99898   6286470
# 99899   4411088
# 99900   4165561
# 99903  11208509
# 99904   2571048
# ...         ...
# 99960   8824122
# 99961   5113152
# 99962   6192555
# 99963   5364140
# 99964   9031758
# 99965   5984032
# 99966   2970720
# 99967   1850100
# 99969   9551384
# 99971   4827697
# 99972     32719
# 99973   1741852
# 99974   4580139
# 99976     36669
# 99977   3998101
# 99978   3773271
# 99980   7329363
# 99981   9681540
# 99983  10146452
# 99984   2206167
# 99985   2082981
# 99987   9929693
# 99988   6309859
# 99989   7076623
# 99990   7282012
# 99991   9536734
# 99992   3549860
# 99994   9897032
# 99998   5762980
# 99999   6926465
#
#                                                                                                                                                     verbatim  \
# 99863                                                                                                                                      Code: 0x80072F78.
# 99865                                                                                          Audio cannot be played even though audio driver is installed.
# 99866                                                                           Birthday. Birthdays that were registered in people are too slow to propagate
# 99867                                     Code: 0x80070057. This download has been trying to complete itself for over a week! The rest are very, very, slow!
# 99868  My Surface Book 2 is connected to Surface Dock via Ethernet on the company network. After about 4-6 hours, the Ethernet disappears and is no longe...
# 99869                                                                           Bluetooth devices can be disconnected, although recognized as being related.
# 99870                                                                                                               Bluetooth paired but unable to connect..
# 99871                                                                                                                                      Code: 0x80070422.
# 99872                                                                                                                ACG [test] from NEBA-XDWEHG88 - Ignore.
# 99873                                                                                                               ACG [test] from RR1WDGTEST0343 - Ignore.
# 99876                                                                                                            Code: 0x80073CF0. unable to reinstall Forza
# 99878                                                                                                                                         AUDIU. NOT SAM
# 99881                                                                                                                                      Code: 0x80073CF9.
# 99882                                                                                                        Code: 0x80073D05. Twitter not working. Crashes.
# 99883              Windows 10, Version 1709 feature Update  cannot be run   Running  Windows 10, Version 1709 feature update  causes errors like screenshots
# 99884                                                                                                               Code: 0x803F8001. Mahjong is installable
# 99885  Worst Laptop   I have purchased this laptop recently and its taking 15 min to start functioning. I have spent 50000 rs to purchase and such a bad ...
# 99886  Give us a 'have read it' option or stop showing ancient - news which is thus not new.  Put the time and date on every entry! Many articles - just ...
# 99888                                                                                                                   some keyboard letter not functional.
# 99891            glitches in windows.. explorer and apps work fine... but windows startbar and windows settings   images and text gets glitched  and jumbled
# 99892                                               Dailyhunt app not open and automatic close this app. Dailyhunt app not open and automatic close this app
# 99894  SYSTEM Runaway Nuisance   I'm very annoyed at the beginning of an abnormal runaway SYSTEM to NORTON. Why is it just after recovery? It's an act of...
# 99895  Printing fit to page   Hi there, Some students benefit from having printed notes from my one note pages. So it's helpful to be able to drop my les...
# 99896                                                                                        Always disconnected from local share folder in the same office.
# 99897                                                         Themes not updating. Installed 2 themes from the Windows store. They do not show up in Themes.
# 99898          Stop inflicting Msn on user's. I wat to have a start up on a page other tha msn and I have tried to change  home page to something less crap.
# 99899                                                                                                                                      Code: 0x00000190.
# 99900                                                                                   am unable to  write in note app,so please help me.how should I use..
# 99903                                                                                                                         Code: 0x803F8001. cant install
# 99904                                                                                                                    Could not mengabil images scrensot.
# ...                                                                                                                                                      ...
# 99960                                                                             CA almost worked!. Why is there no connection microsioft the chiotes puppy
# 99961  Need the features of the rest of the Office suite.. All of the toolbars a have access to the PowerPoint (animation, and shape/image manipulation c...
# 99962  this usb is either useless or the seller is useless or the franchising company is useless got the rubbish for a usb and nothing is working disgust...
# 99963                                                                                                  audio. speaking in the regional and language settings
# 99964                        no setup device option in ring app windows 10. I want to set up ring app in windows 10 but there is no option for device set up
# 99965                                                                                                                              in currency propal golas.
# 99966                                                                                                          Code: 0x80131500 The App Store has been open.
# 99967                                                                                       did not access SCAN. couldn't adjust Epson WF-7610 to allow scan
# 99969                                                                                                      Windows Update Windows Update Update Updates. 100
# 99971  Please improve the app functionality. I'm a Windows fan, but I tried to send an email 3 times from the Mail App with no success, and.... ...finall...
# 99972  Task Bar keeps flashing / redrawing.  Distracting.. Taskbar flashing and redrawing detracts from overall windows experience. Very similar to rapid...
# 99973                                                                                               Unable to display this page https://search.yahoo.co.jp/|
# 99974                                                                                                                         PRINTER. DEFAULT PRINTER ERROR
# 99976      Code: 0x80244007   Trying to download Forza Horizon 4. Downloaded 69gb and then received error about installing  Cannot install, will try shortly
# 99977  Impossible to reach this page https://cdllife.com/2019/trucker-shot-truck-stop-declining-sex-money/?fbclid=IwAR0mK-JsYW7JjeqtuM1y9c_qbDABz6_bxZwC7...
# 99978  My user name. In the name of all that is holy would you name my user account with my email address????  What kind of fucked up rationale is that??...
# 99980                                                                                                                                           please solve
# 99981                               Can t reach this page http://http-download.intuit.com/http.intuit/QBDT_HELP/QBDTUrlRedirect.html?QBURL_ID=article000031.
# 99983                                                                                                                                       Code: 0x80131500
# 99984  Two-step validation. Request Authenticator from Microsoft comes only from the second-third times after his call. Faster total request comes after ...
# 99985  Device Portal 3D view page  it's lonely here    I was using the device portal page to connect to hololens.  I was able to use the 3D view page in ...
# 99987                                                                                                [] 0xc00007b error   . wont load and I get this message
# 99988  Make Windows 10 like Windows 7 or even Windows XP for user interface. I worked for years in aviation in human factors.  I have used Windows 10 for...
# 99989                                                                                             Code: 0x80131505. Download wallpapers can't open web pages
# 99990                                                                                                                            system going slow pls fast.
# 99991                                                                                                              Code: 0x80072EFD. why it does not install
# 99992                                                                                                        ebay.com.au. Screens fucked like it has a virus
# 99994                                                                                                      sound and audio devices properties is not working
# 99998                                               audio. I cannot hear the audio very well, making a call can not hear clearly what the other person says.
# 99999                                                                                  Jem & the Holograms (Truly Outrageous A Tribute to Starlight Records)
#
#        word_count  \
# 99863           2
# 99865          10
# 99866          12
# 99867          20
# 99868          68
# 99869          10
# 99870           6
# 99871           2
# 99872           6
# 99873           6
# 99876           6
# 99878           3
# 99881           2
# 99882           6
# 99883          20
# 99884           5
# 99885          56
# 99886          31
# 99888           5
# 99891          21
# 99892          18
# 99894          27
# 99895          63
# 99896          10
# 99897          17
# 99898          30
# 99899           2
# 99900          13
# 99903           4
# 99904           5
# ...           ...
# 99960          12
# 99961          56
# 99962          28
# 99963           8
# 99964          28
# 99965           4
# 99966           8
# 99967          11
# 99969           7
# 99971          45
# 99972          36
# 99973           6
# 99974           4
# 99976          21
# 99977           7
# 99978          44
# 99980           2
# 99981           6
# 99983           2
# 99984          37
# 99985          70
# 99987          11
# 99988         103
# 99989           8
# 99990           5
# 99991           7
# 99992           8
# 99994           8
# 99998          20
# 99999          11
#
#                                                                                                                                           verbatim_processed
# 99863                                                                                                                                      Code: 0x80072F78.
# 99865                                                                                          Audio cannot be played even though audio driver is installed.
# 99866                                                                           Birthday. Birthdays that were registered in people are too slow to propagate
# 99867                                     Code: 0x80070057. This download has been trying to complete itself for over a week! The rest are very, very, slow!
# 99868  My Surface Book 2 is connected to Surface Dock via Ethernet on the company network. After about 4-6 hours, the Ethernet disappears and is no longe...
# 99869                                                                           Bluetooth devices can be disconnected, although recognized as being related.
# 99870                                                                                                               Bluetooth paired but unable to connect..
# 99871                                                                                                                                      Code: 0x80070422.
# 99872                                                                                                                ACG [test] from NEBA-XDWEHG88 - Ignore.
# 99873                                                                                                               ACG [test] from RR1WDGTEST0343 - Ignore.
# 99876                                                                                                            Code: 0x80073CF0. unable to reinstall Forza
# 99878                                                                                                                                         AUDIU. NOT SAM
# 99881                                                                                                                                      Code: 0x80073CF9.
# 99882                                                                                                        Code: 0x80073D05. Twitter not working. Crashes.
# 99883              Windows 10, Version 1709 feature Update  cannot be run   Running  Windows 10, Version 1709 feature update  causes errors like screenshots
# 99884                                                                                                               Code: 0x803F8001. Mahjong is installable
# 99885  Worst Laptop   I have purchased this laptop recently and its taking 15 min to start functioning. I have spent 50000 rs to purchase and such a bad ...
# 99886  Give us a 'have read it' option or stop showing ancient - news which is thus not new.  Put the time and date on every entry! Many articles - just ...
# 99888                                                                                                                   some keyboard letter not functional.
# 99891            glitches in windows.. explorer and apps work fine... but windows startbar and windows settings   images and text gets glitched  and jumbled
# 99892                                               Dailyhunt app not open and automatic close this app. Dailyhunt app not open and automatic close this app
# 99894  SYSTEM Runaway Nuisance   I am very annoyed at the beginning of an abnormal runaway SYSTEM to NORTON. Why is it just after recovery? it is an act ...
# 99895  Printing fit to page   Hi there, Some students benefit from having printed notes from my one note pages. So it is helpful to be able to drop my le...
# 99896                                                                                        Always disconnected from local share folder in the same office.
# 99897                                                         Themes not updating. Installed 2 themes from the Windows store. They do not show up in Themes.
# 99898          Stop inflicting Msn on user's. I wat to have a start up on a page other tha msn and I have tried to change  home page to something less crap.
# 99899                                                                                                                                      Code: 0x00000190.
# 99900                                                                                   am unable to  write in note app,so please help me.how should I use..
# 99903                                                                                                                      Code: 0x803F8001. can not install
# 99904                                                                                                                    Could not mengabil images scrensot.
# ...                                                                                                                                                      ...
# 99960                                                                             CA almost worked!. Why is there no connection microsioft the chiotes puppy
# 99961  Need the features of the rest of the Office suite.. All of the toolbars a have access to the PowerPoint (animation, and shape/image manipulation c...
# 99962  this usb is either useless or the seller is useless or the franchising company is useless got the rubbish for a usb and nothing is working disgust...
# 99963                                                                                                  audio. speaking in the regional and language settings
# 99964                        no setup device option in ring app windows 10. I want to set up ring app in windows 10 but there is no option for device set up
# 99965                                                                                                                              in currency propal golas.
# 99966                                                                                                          Code: 0x80131500 The App Store has been open.
# 99967                                                                                      did not access SCAN. could not adjust Epson WF-7610 to allow scan
# 99969                                                                                                      Windows Update Windows Update Update Updates. 100
# 99971  Please improve the app functionality. I am a Windows fan, but I tried to send an email 3 times from the Mail App with no success, and.... ...final...
# 99972  Task Bar keeps flashing / redrawing.  Distracting.. Taskbar flashing and redrawing detracts from overall windows experience. Very similar to rapid...
# 99973                                                                                               Unable to display this page https://search.yahoo.co.jp/|
# 99974                                                                                                                         PRINTER. DEFAULT PRINTER ERROR
# 99976      Code: 0x80244007   Trying to download Forza Horizon 4. Downloaded 69gb and then received error about installing  Cannot install, will try shortly
# 99977  Impossible to reach this page https://cdllife.com/2019/trucker-shot-truck-stop-declining-sex-money/?fbclid=IwAR0mK-JsYW7JjeqtuM1y9c_qbDABz6_bxZwC7...
# 99978  My user name. In the name of all that is holy would you name my user account with my email address????  What kind of fucked up rationale is that??...
# 99980                                                                                                                                           please solve
# 99981                               Can t reach this page http://http-download.intuit.com/http.intuit/QBDT_HELP/QBDTUrlRedirect.html?QBURL_ID=article000031.
# 99983                                                                                                                                       Code: 0x80131500
# 99984  Two-step validation. Request Authenticator from Microsoft comes only from the second-third times after his call. Faster total request comes after ...
# 99985  Device Portal 3D view page  it is lonely here    I was using the device portal page to connect to hololens.  I was able to use the 3D view page in...
# 99987                                                                                            [] 0xc00007b error   . will not load and I get this message
# 99988  Make Windows 10 like Windows 7 or even Windows XP for user interface. I worked for years in aviation in human factors.  I have used Windows 10 for...
# 99989                                                                                           Code: 0x80131505. Download wallpapers can not open web pages
# 99990                                                                                                                            system going slow pls fast.
# 99991                                                                                                              Code: 0x80072EFD. why it does not install
# 99992                                                                                                        ebay.com.au. Screens fucked like it has a virus
# 99994                                                                                                      sound and audio devices properties is not working
# 99998                                               audio. I cannot hear the audio very well, making a call can not hear clearly what the other person says.
# 99999                                                                                  Jem & the Holograms (Truly Outrageous A Tribute to Starlight Records)
#
# [100 rows x 4 columns]

# %%
print (uif.shape)
print (uif_clean.shape)
uif_clean.tail(100)
# Out:
# (70672, 4)
# (58761, 4)
#              Id  \
# 99840   9630786
# 99842   2378303
# 99843   8323781
# 99844   5960357
# 99846   2614588
# 99847   8827409
# 99848  10369396
# 99852   8616137
# 99855   3498857
# 99857  11223947
# 99858   5472747
# 99859   4197058
# 99860   1015672
# 99862   7231088
# 99865   4967024
# 99866   5956972
# 99867   9683155
# 99868   6637733
# 99869   2164214
# 99870   3825001
# 99872   9715512
# 99873   6334109
# 99876   7008958
# 99882  11818082
# 99883   3836902
# 99884    885762
# 99885   3815269
# 99886    101450
# 99888   9158057
# 99891   3178312
# ...         ...
# 99955   7186392
# 99959   6606540
# 99960   8824122
# 99961   5113152
# 99962   6192555
# 99963   5364140
# 99964   9031758
# 99965   5984032
# 99966   2970720
# 99967   1850100
# 99969   9551384
# 99971   4827697
# 99972     32719
# 99973   1741852
# 99974   4580139
# 99976     36669
# 99977   3998101
# 99978   3773271
# 99981   9681540
# 99984   2206167
# 99985   2082981
# 99987   9929693
# 99988   6309859
# 99989   7076623
# 99990   7282012
# 99991   9536734
# 99992   3549860
# 99994   9897032
# 99998   5762980
# 99999   6926465
#
#                                                                                                                                                     verbatim  \
# 99840  I haven't ben able to use my 11.62 Euros since you upgraded.    I have 11.62 Euros which I needed and used to phone my cousins  in Australia. I ca...
# 99842                                                                                                  Code: 0x80070422. does not install the programs error
# 99843                                                                                                                   Useless. Problem was not identified.
# 99844  Online contacts - Skype screen size   No  online only contacts option, huge skype app - why take a good product and make it difficult yet again Mi...
# 99846                                                                                                                  ACG [test] from G-2323D0153 - Ignore.
# 99847  app does not work properly. Security Center tells me that there is an app that doesn't work correctly, but does not tell me which. what should I d...
# 99848                                                                             nothing can be heard. that not there volume or you can climb the volume as
# 99852                                             This page is having a problem loading https://apps.facebook.com/papapear/?fb_source=bookmark. It wont load
# 99855                                                                    Problems with birthdays calendars-birthday is missing, cannot add new birthday, etc
# 99857                                                                                                      Code: 0X80131500. The win10 App Store won't open.
# 99858                                                                                                          [.exe] are wrong. a malware to destroyed .exe
# 99859  [] Version 1809 is not compatible with the NVIDA2070417.71 driver. There are frequent card owners or flashbacks when playing games, and version 17...
# 99860                                                                       On Build 18272 Right clicking in explorer pane on a drive crashes file explorer.
# 99862                                                  There is a problem with the system. There was a problem saving the picture pop-up system in the video
# 99865                                                                                          Audio cannot be played even though audio driver is installed.
# 99866                                                                           Birthday. Birthdays that were registered in people are too slow to propagate
# 99867                                     Code: 0x80070057. This download has been trying to complete itself for over a week! The rest are very, very, slow!
# 99868  My Surface Book 2 is connected to Surface Dock via Ethernet on the company network. After about 4-6 hours, the Ethernet disappears and is no longe...
# 99869                                                                           Bluetooth devices can be disconnected, although recognized as being related.
# 99870                                                                                                               Bluetooth paired but unable to connect..
# 99872                                                                                                                ACG [test] from NEBA-XDWEHG88 - Ignore.
# 99873                                                                                                               ACG [test] from RR1WDGTEST0343 - Ignore.
# 99876                                                                                                            Code: 0x80073CF0. unable to reinstall Forza
# 99882                                                                                                        Code: 0x80073D05. Twitter not working. Crashes.
# 99883              Windows 10, Version 1709 feature Update  cannot be run   Running  Windows 10, Version 1709 feature update  causes errors like screenshots
# 99884                                                                                                               Code: 0x803F8001. Mahjong is installable
# 99885  Worst Laptop   I have purchased this laptop recently and its taking 15 min to start functioning. I have spent 50000 rs to purchase and such a bad ...
# 99886  Give us a 'have read it' option or stop showing ancient - news which is thus not new.  Put the time and date on every entry! Many articles - just ...
# 99888                                                                                                                   some keyboard letter not functional.
# 99891            glitches in windows.. explorer and apps work fine... but windows startbar and windows settings   images and text gets glitched  and jumbled
# ...                                                                                                                                                      ...
# 99955                                                                                                           Can t reach this page https://www.ebay.com/.
# 99959  Windows Update does not finalizes the new version. I am since yesterday trying to finalize the installation of the new version 1903 and is in the ...
# 99960                                                                             CA almost worked!. Why is there no connection microsioft the chiotes puppy
# 99961  Need the features of the rest of the Office suite.. All of the toolbars a have access to the PowerPoint (animation, and shape/image manipulation c...
# 99962  this usb is either useless or the seller is useless or the franchising company is useless got the rubbish for a usb and nothing is working disgust...
# 99963                                                                                                  audio. speaking in the regional and language settings
# 99964                        no setup device option in ring app windows 10. I want to set up ring app in windows 10 but there is no option for device set up
# 99965                                                                                                                              in currency propal golas.
# 99966                                                                                                          Code: 0x80131500 The App Store has been open.
# 99967                                                                                       did not access SCAN. couldn't adjust Epson WF-7610 to allow scan
# 99969                                                                                                      Windows Update Windows Update Update Updates. 100
# 99971  Please improve the app functionality. I'm a Windows fan, but I tried to send an email 3 times from the Mail App with no success, and.... ...finall...
# 99972  Task Bar keeps flashing / redrawing.  Distracting.. Taskbar flashing and redrawing detracts from overall windows experience. Very similar to rapid...
# 99973                                                                                               Unable to display this page https://search.yahoo.co.jp/|
# 99974                                                                                                                         PRINTER. DEFAULT PRINTER ERROR
# 99976      Code: 0x80244007   Trying to download Forza Horizon 4. Downloaded 69gb and then received error about installing  Cannot install, will try shortly
# 99977  Impossible to reach this page https://cdllife.com/2019/trucker-shot-truck-stop-declining-sex-money/?fbclid=IwAR0mK-JsYW7JjeqtuM1y9c_qbDABz6_bxZwC7...
# 99978  My user name. In the name of all that is holy would you name my user account with my email address????  What kind of fucked up rationale is that??...
# 99981                               Can t reach this page http://http-download.intuit.com/http.intuit/QBDT_HELP/QBDTUrlRedirect.html?QBURL_ID=article000031.
# 99984  Two-step validation. Request Authenticator from Microsoft comes only from the second-third times after his call. Faster total request comes after ...
# 99985  Device Portal 3D view page  it's lonely here    I was using the device portal page to connect to hololens.  I was able to use the 3D view page in ...
# 99987                                                                                                [] 0xc00007b error   . wont load and I get this message
# 99988  Make Windows 10 like Windows 7 or even Windows XP for user interface. I worked for years in aviation in human factors.  I have used Windows 10 for...
# 99989                                                                                             Code: 0x80131505. Download wallpapers can't open web pages
# 99990                                                                                                                            system going slow pls fast.
# 99991                                                                                                              Code: 0x80072EFD. why it does not install
# 99992                                                                                                        ebay.com.au. Screens fucked like it has a virus
# 99994                                                                                                      sound and audio devices properties is not working
# 99998                                               audio. I cannot hear the audio very well, making a call can not hear clearly what the other person says.
# 99999                                                                                  Jem & the Holograms (Truly Outrageous A Tribute to Starlight Records)
#
#        word_count  \
# 99840          73
# 99842           8
# 99843           5
# 99844          27
# 99846           6
# 99847          42
# 99848          15
# 99852          11
# 99855          11
# 99857           8
# 99858           8
# 99859          28
# 99860          14
# 99862          19
# 99865          10
# 99866          12
# 99867          20
# 99868          68
# 99869          10
# 99870           6
# 99872           6
# 99873           6
# 99876           6
# 99882           6
# 99883          20
# 99884           5
# 99885          56
# 99886          31
# 99888           5
# 99891          21
# ...           ...
# 99955           6
# 99959          35
# 99960          12
# 99961          56
# 99962          28
# 99963           8
# 99964          28
# 99965           4
# 99966           8
# 99967          11
# 99969           7
# 99971          45
# 99972          36
# 99973           6
# 99974           4
# 99976          21
# 99977           7
# 99978          44
# 99981           6
# 99984          37
# 99985          70
# 99987          11
# 99988         103
# 99989           8
# 99990           5
# 99991           7
# 99992           8
# 99994           8
# 99998          20
# 99999          11
#
#                                                                                                                                           verbatim_processed
# 99840  I have not ben able to use my 11.62 Euros since you upgraded.    I have 11.62 Euros which I needed and used to phone my cousins  in Australia. I c...
# 99842                                                                                                  Code: 0x80070422. does not install the programs error
# 99843                                                                                                                   Useless. Problem was not identified.
# 99844  Online contacts - Skype screen size   No  online only contacts option, huge skype app - why take a good product and make it difficult yet again Mi...
# 99846                                                                                                                  ACG [test] from G-2323D0153 - Ignore.
# 99847  app does not work properly. Security Center tells me that there is an app that does not work correctly, but does not tell me which. what should I ...
# 99848                                                                             nothing can be heard. that not there volume or you can climb the volume as
# 99852                                         This page is having a problem loading https://apps.facebook.com/papapear/?fb_source=bookmark. It will not load
# 99855                                                                    Problems with birthdays calendars-birthday is missing, cannot add new birthday, etc
# 99857                                                                                                   Code: 0X80131500. The win10 App Store will not open.
# 99858                                                                                                          [.exe] are wrong. a malware to destroyed .exe
# 99859  [] Version 1809 is not compatible with the NVIDA2070417.71 driver. There are frequent card owners or flashbacks when playing games, and version 17...
# 99860                                                                       On Build 18272 Right clicking in explorer pane on a drive crashes file explorer.
# 99862                                                  There is a problem with the system. There was a problem saving the picture pop-up system in the video
# 99865                                                                                          Audio cannot be played even though audio driver is installed.
# 99866                                                                           Birthday. Birthdays that were registered in people are too slow to propagate
# 99867                                     Code: 0x80070057. This download has been trying to complete itself for over a week! The rest are very, very, slow!
# 99868  My Surface Book 2 is connected to Surface Dock via Ethernet on the company network. After about 4-6 hours, the Ethernet disappears and is no longe...
# 99869                                                                           Bluetooth devices can be disconnected, although recognized as being related.
# 99870                                                                                                               Bluetooth paired but unable to connect..
# 99872                                                                                                                ACG [test] from NEBA-XDWEHG88 - Ignore.
# 99873                                                                                                               ACG [test] from RR1WDGTEST0343 - Ignore.
# 99876                                                                                                            Code: 0x80073CF0. unable to reinstall Forza
# 99882                                                                                                        Code: 0x80073D05. Twitter not working. Crashes.
# 99883              Windows 10, Version 1709 feature Update  cannot be run   Running  Windows 10, Version 1709 feature update  causes errors like screenshots
# 99884                                                                                                               Code: 0x803F8001. Mahjong is installable
# 99885  Worst Laptop   I have purchased this laptop recently and its taking 15 min to start functioning. I have spent 50000 rs to purchase and such a bad ...
# 99886  Give us a 'have read it' option or stop showing ancient - news which is thus not new.  Put the time and date on every entry! Many articles - just ...
# 99888                                                                                                                   some keyboard letter not functional.
# 99891            glitches in windows.. explorer and apps work fine... but windows startbar and windows settings   images and text gets glitched  and jumbled
# ...                                                                                                                                                      ...
# 99955                                                                                                           Can t reach this page https://www.ebay.com/.
# 99959  Windows Update does not finalizes the new version. I am since yesterday trying to finalize the installation of the new version 1903 and is in the ...
# 99960                                                                             CA almost worked!. Why is there no connection microsioft the chiotes puppy
# 99961  Need the features of the rest of the Office suite.. All of the toolbars a have access to the PowerPoint (animation, and shape/image manipulation c...
# 99962  this usb is either useless or the seller is useless or the franchising company is useless got the rubbish for a usb and nothing is working disgust...
# 99963                                                                                                  audio. speaking in the regional and language settings
# 99964                        no setup device option in ring app windows 10. I want to set up ring app in windows 10 but there is no option for device set up
# 99965                                                                                                                              in currency propal golas.
# 99966                                                                                                          Code: 0x80131500 The App Store has been open.
# 99967                                                                                      did not access SCAN. could not adjust Epson WF-7610 to allow scan
# 99969                                                                                                      Windows Update Windows Update Update Updates. 100
# 99971  Please improve the app functionality. I am a Windows fan, but I tried to send an email 3 times from the Mail App with no success, and.... ...final...
# 99972  Task Bar keeps flashing / redrawing.  Distracting.. Taskbar flashing and redrawing detracts from overall windows experience. Very similar to rapid...
# 99973                                                                                               Unable to display this page https://search.yahoo.co.jp/|
# 99974                                                                                                                         PRINTER. DEFAULT PRINTER ERROR
# 99976      Code: 0x80244007   Trying to download Forza Horizon 4. Downloaded 69gb and then received error about installing  Cannot install, will try shortly
# 99977  Impossible to reach this page https://cdllife.com/2019/trucker-shot-truck-stop-declining-sex-money/?fbclid=IwAR0mK-JsYW7JjeqtuM1y9c_qbDABz6_bxZwC7...
# 99978  My user name. In the name of all that is holy would you name my user account with my email address????  What kind of fucked up rationale is that??...
# 99981                               Can t reach this page http://http-download.intuit.com/http.intuit/QBDT_HELP/QBDTUrlRedirect.html?QBURL_ID=article000031.
# 99984  Two-step validation. Request Authenticator from Microsoft comes only from the second-third times after his call. Faster total request comes after ...
# 99985  Device Portal 3D view page  it is lonely here    I was using the device portal page to connect to hololens.  I was able to use the 3D view page in...
# 99987                                                                                            [] 0xc00007b error   . will not load and I get this message
# 99988  Make Windows 10 like Windows 7 or even Windows XP for user interface. I worked for years in aviation in human factors.  I have used Windows 10 for...
# 99989                                                                                           Code: 0x80131505. Download wallpapers can not open web pages
# 99990                                                                                                                            system going slow pls fast.
# 99991                                                                                                              Code: 0x80072EFD. why it does not install
# 99992                                                                                                        ebay.com.au. Screens fucked like it has a virus
# 99994                                                                                                      sound and audio devices properties is not working
# 99998                                               audio. I cannot hear the audio very well, making a call can not hear clearly what the other person says.
# 99999                                                                                  Jem & the Holograms (Truly Outrageous A Tribute to Starlight Records)
#
# [100 rows x 4 columns]

# %%
uif['word_count'] = uif['verbatim'].apply(lambda x: len(x.split()))
uif_clean = uif[uif['word_count'] > 3]
uif_clean.shape
# Out:
# (58761, 3)

# %% [markdown]
# ## Clean and preprocess text

# %%
def preprocess(text):
    """
    This function performs preprocessing on a single feedback text string. It
    does the following operations:
    - expand contractions
    - convert to lowercase
    - drop all non-alpha characters
 
    INPUTS:
        text = str, feedback verbatim string
    OUTPUTS:
        text = str, preprocessed verbatim string
    """
    # get rid of #DELIM#
    text = text.replace("#DELIM#", "")
    # fix contractions
    text = contractions.fix(text)
    return text

# %%
uif_clean['verbatim_processed'] = uif_clean['verbatim'].apply(lambda verbatim: preprocess(verbatim))
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
uif_clean.shape
# Out:
# (58761, 4)

# %% [markdown]
# ## Sentence Tokenization

# %%
#import spacy
#!pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz --no-deps
nlp = spacy.load("en_core_web_sm")

# %%
# custom tokenizer class
prefix_re = re.compile(r'''^[[("']''')
suffix_re = re.compile(r'''[])"']$''')
infix_re = re.compile(r'''[-~]''')
simple_url_re = re.compile(r'''^https?://''')

def custom_tokenizer(nlp):
    return Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
                                suffix_search=suffix_re.search,
                                infix_finditer=infix_re.finditer,
                                token_match=simple_url_re.match)

#nlp = spacy.load("en_core_web_sm")
nlp.tokenizer = custom_tokenizer(nlp)
doc = nlp(uif_clean['verbatim'].iloc[3])
print([t.text for t in doc])
# Out:
# ['OneNote', 'does', 'not', 'open.']

# %%
# nlp.add_pipe(nlp.create_pipe('sentencizer'), before="parser")
uif_clean['text'] = uif_clean['verbatim_processed'].apply(lambda x: [sent.string.strip() for sent in nlp(x).sents])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-3e563a8c87dc> in <module>
#       1 # nlp.add_pipe(nlp.create_pipe('sentencizer'), before="parser")
# ----> 2 uif_clean['text'] = uif_clean['verbatim_processed'].apply(lambda x: [sent.string.strip() for sent in nlp(x).sents])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-43-3e563a8c87dc> in <lambda>(x)
#       1 # nlp.add_pipe(nlp.create_pipe('sentencizer'), before="parser")
# ----> 2 uif_clean['text'] = uif_clean['verbatim_processed'].apply(lambda x: [sent.string.strip() for sent in nlp(x).sents])
#
# ~\Anaconda3\lib\site-packages\spacy\language.py in __call__(self, text, disable, component_cfg)
#     393             if not hasattr(proc, "__call__"):
#     394                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 395             doc = proc(doc, **component_cfg.get(name, {}))
#     396             if doc is None:
#     397                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.predict()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.greedy_parse()
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# ~\Anaconda3\lib\site-packages\thinc\neural\_classes\model.py in predict(self, X)
#     131
#     132     def predict(self, X):
# --> 133         y, _ = self.begin_update(X, drop=None)
#     134         return y
#     135
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserModel.begin_update()
#
# _parser_model.pyx in spacy.syntax._parser_model.ParserStepModel.__init__()
#
# _parser_model.pyx in spacy.syntax._parser_model.precompute_hiddens.__init__()
#
# ~\Anaconda3\lib\site-packages\spacy\_ml.py in begin_update(self, X, drop)
#     180     def begin_update(self, X, drop=0.0):
#     181         Yf = self.ops.gemm(
# --> 182             X, self.W.reshape((self.nF * self.nO * self.nP, self.nI)), trans2=True
#     183         )
#     184         Yf = Yf.reshape((Yf.shape[0], self.nF, self.nO, self.nP))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Save to text file

# %%
with open('./uif_pretrain_100k_No_Space.txt', 'w') as f:
    for fb in uif_clean['verbatim_processed']:
        f.write("%s\n" % fb)
        #for sent in fb:
            #f.write("%s " % sent)
        #f.write("\n")

# %%
uif_clean.shape
# Out:
# (58761, 4)

# %%
print (uif.shape)
# Out:
# (70672, 4)

# %%
print (uif.shape)
print (type(uif['verbatim_processed']))
len(uif['text'].iloc[1])
# Out:
# (8243156, 4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-7a25855b8a0b> in <module>
#       1 print (uif.shape)
# ----> 2 print (type(uif['text']))
#       3 len(uif['text'].iloc[1])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
