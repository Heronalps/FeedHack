# %%
import h5py
import pandas as pd
from collections import OrderedDict 
import numpy as np

# %%
elmo = h5py.File("./checkpoints/weights.hdf5", 'r')   
stack = pd.read_csv("./stack_labeled_feedback.txt", sep='\t')

# %%
output_dict = OrderedDict()
for key in range(len(elmo) - 1):
    #import pdb; pdb.set_trace();
    vector_list = elmo.get(str(key)).value
    output_dict[int(key)] = [stack['ConformedFeedbackId'][int(key)], vector_list]

# %%
df = pd.DataFrame.from_dict(data=output_dict, orient='index')
df.rename(columns={0:'ConformedFeedbackId', 1:'Embeddings'}, inplace=True)

df['Avg_Embeddings'] = df['Embeddings'].apply(lambda vector: np.average(vector, axis=0))
df_avg = pd.concat([df['ConformedFeedbackId'], df['Avg_Embeddings']], axis=1)

df_split = pd.DataFrame(df_avg['Avg_Embeddings'].values.tolist())

df_output = pd.concat([df_avg['ConformedFeedbackId'], df_split], axis=1)

# %%
df_output.head()
# Out:
#                                ConformedFeedbackId         0         1  \
# 0  answerscom|00207682-4f27-4954-9d0a-4a2c657e6a26 -0.015335 -0.071906
# 1  answerscom|00617b78-9f2c-48c4-998c-897074d2fd42 -0.008563  0.214385
# 2  answerscom|0066f9af-a7d4-4dd7-b3a5-8aa9d93dc527 -0.090752 -0.104738
# 3  answerscom|0072cd01-2de3-474a-aae5-cab989f373ca -0.101456 -0.117794
# 4  answerscom|00a7c412-99b9-48aa-a8f8-6defef4c2066  0.106414 -0.025424
#
#           2         3         4         5         6         7         8  \
# 0  0.030063  0.013790  0.128753  0.103720  0.038522  0.170616 -0.526257
# 1 -0.243304 -0.086803 -0.125024 -0.080640 -0.137636  0.321359 -0.395020
# 2 -0.122744 -0.003474  0.218281  0.063667 -0.198489 -0.100923 -0.205531
# 3 -0.231244 -0.047338  0.136798 -0.026347 -0.230015  0.222987 -0.584733
# 4  0.360089  0.005091 -0.013648 -0.009945 -0.081916 -0.002872 -0.243053
#
#      ...         1014      1015      1016      1017      1018      1019  \
# 0    ...    -0.218329  0.091694 -0.087266 -0.078283  0.146074  0.041991
# 1    ...    -0.301509  0.292160 -0.031629  0.027544 -0.121716  0.335798
# 2    ...    -0.309846  0.217954 -0.119436  0.114715 -0.044627 -0.112134
# 3    ...    -0.138848  0.289886  0.077002 -0.207100  0.049893  0.258696
# 4    ...     0.011970 -0.098121  0.234268 -0.028895  0.101512  0.091571
#
#        1020      1021      1022      1023
# 0  0.222039 -0.066200  0.114263 -0.004985
# 1  0.704026 -0.044195  0.013833  0.081883
# 2  0.140360 -0.210917  0.102854 -0.045492
# 3  0.310412 -0.050415  0.171502  0.064545
# 4 -0.309413 -0.159074  0.055116  0.092716
#
# [5 rows x 1025 columns]

# %%
df_output.to_csv("./embed.csv", header=True, index=False)

# %%
df_test = pd.read_csv("./embed.csv")
df_test.head()
# Out:
#                                ConformedFeedbackId         0         1  \
# 0  answerscom|00207682-4f27-4954-9d0a-4a2c657e6a26 -0.015335 -0.071906
# 1  answerscom|00617b78-9f2c-48c4-998c-897074d2fd42 -0.008563  0.214385
# 2  answerscom|0066f9af-a7d4-4dd7-b3a5-8aa9d93dc527 -0.090752 -0.104738
# 3  answerscom|0072cd01-2de3-474a-aae5-cab989f373ca -0.101456 -0.117794
# 4  answerscom|00a7c412-99b9-48aa-a8f8-6defef4c2066  0.106414 -0.025424
#
#           2         3         4         5         6         7         8  \
# 0  0.030063  0.013790  0.128753  0.103720  0.038522  0.170616 -0.526257
# 1 -0.243304 -0.086803 -0.125024 -0.080640 -0.137636  0.321359 -0.395020
# 2 -0.122744 -0.003474  0.218281  0.063667 -0.198489 -0.100923 -0.205531
# 3 -0.231244 -0.047338  0.136798 -0.026347 -0.230015  0.222987 -0.584733
# 4  0.360089  0.005091 -0.013648 -0.009945 -0.081916 -0.002872 -0.243053
#
#      ...         1014      1015      1016      1017      1018      1019  \
# 0    ...    -0.218329  0.091694 -0.087266 -0.078283  0.146074  0.041991
# 1    ...    -0.301509  0.292160 -0.031629  0.027544 -0.121716  0.335798
# 2    ...    -0.309846  0.217954 -0.119436  0.114715 -0.044627 -0.112134
# 3    ...    -0.138848  0.289886  0.077002 -0.207100  0.049893  0.258696
# 4    ...     0.011970 -0.098121  0.234268 -0.028895  0.101512  0.091571
#
#        1020      1021      1022      1023
# 0  0.222039 -0.066200  0.114263 -0.004985
# 1  0.704026 -0.044195  0.013833  0.081883
# 2  0.140360 -0.210917  0.102854 -0.045492
# 3  0.310412 -0.050415  0.171502  0.064545
# 4 -0.309413 -0.159074  0.055116  0.092716
#
# [5 rows x 1025 columns]
